# %%
#!pip install pybaseball
# Out:
# Collecting pybaseball
#   Downloading pybaseball-2.2.7-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (2.0.2)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (2.2.2)
# Requirement already satisfied: beautifulsoup4>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (4.13.3)
# Requirement already satisfied: requests>=2.18.1 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (2.32.3)
# Requirement already satisfied: lxml>=4.2.1 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (5.3.1)
# Requirement already satisfied: pyarrow>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (18.1.0)
# Collecting pygithub>=1.51 (from pybaseball)
#   Downloading PyGithub-2.6.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (1.14.1)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (3.10.0)
# Requirement already satisfied: tqdm>=4.50.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (4.67.1)
# Requirement already satisfied: attrs>=20.3.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (25.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.0->pybaseball) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.0->pybaseball) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.3->pybaseball) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.3->pybaseball) (2025.1)
# Collecting pynacl>=1.4.0 (from pygithub>=1.51->pybaseball)
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (2.10.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from pygithub>=1.51->pybaseball) (2.3.0)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.11/dist-packages (from pygithub>=1.51->pybaseball) (1.2.18)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.1->pybaseball) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.1->pybaseball) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.1->pybaseball) (2025.1.31)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (43.0.3)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pynacl>=1.4.0->pygithub>=1.51->pybaseball) (1.17.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pybaseball) (1.17.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated->pygithub>=1.51->pybaseball) (1.17.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub>=1.51->pybaseball) (2.22)
# Downloading pybaseball-2.2.7-py3-none-any.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.1/426.1 kB 11.1 MB/s eta 0:00:00
# Downloading PyGithub-2.6.1-py3-none-any.whl (410 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 17.3 MB/s eta 0:00:00
# Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 35.5 MB/s eta 0:00:00
# Installing collected packages: pynacl, pygithub, pybaseball
# Successfully installed pybaseball-2.2.7 pygithub-2.6.1 pynacl-1.5.0

# %%
## Importing Libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
## Loading in Data
sale = pd.read_csv('/content/sale_2024_cleaned.csv')
skubal = pd.read_csv('/content/skubal_2024_cleaned.csv')

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2815 entries, 0 to 2814
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pitch_type         2815 non-null   object
#  1   release_speed      2815 non-null   float64
#  2   release_pos_x      2815 non-null   float64
#  3   release_pos_y      2815 non-null   float64
#  4   release_pos_z      2815 non-null   float64
#  5   release_spin_rate  2815 non-null   int64
#  6   spin_axis          2815 non-null   int64
#  7   pfx_x              2815 non-null   float64
#  8   pfx_z              2815 non-null   float64
#  9   plate_x            2815 non-null   float64
#  10  plate_z            2815 non-null   float64
#  11  sz_top             2815 non-null   float64
#  12  sz_bot             2815 non-null   float64
#  13  balls              2815 non-null   int64
#  14  strikes            2815 non-null   int64
#  15  outs_when_up       2815 non-null   int64
#  16  inning             2815 non-null   int64
#  17  inning_topbot      2815 non-null   object
#  18  stand              2815 non-null   object
#  19  p_throws           2815 non-null   object
#  20  bat_score          2815 non-null   int64
#  21  fld_score          2815 non-null   int64
#  22  at_bat_number      2815 non-null   int64
#  23  pitch_number       2815 non-null   int64
#  24  game_pk            2815 non-null   int64
#  25  batter             2815 non-null   int64
#  26  pitcher            2815 non-null   int64
#  27  description        2815 non-null   object
#  28  events             2815 non-null   object
# dtypes: float64(10), int64(13), object(6)
# memory usage: 637.9+ KB

# %%
skubal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3098 entries, 0 to 3097
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pitch_type         3098 non-null   object
#  1   release_speed      3098 non-null   float64
#  2   release_pos_x      3098 non-null   float64
#  3   release_pos_y      3098 non-null   float64
#  4   release_pos_z      3098 non-null   float64
#  5   release_spin_rate  3098 non-null   float64
#  6   spin_axis          3098 non-null   float64
#  7   pfx_x              3098 non-null   float64
#  8   pfx_z              3098 non-null   float64
#  9   plate_x            3098 non-null   float64
#  10  plate_z            3098 non-null   float64
#  11  sz_top             3098 non-null   float64
#  12  sz_bot             3098 non-null   float64
#  13  balls              3098 non-null   int64
#  14  strikes            3098 non-null   int64
#  15  outs_when_up       3098 non-null   int64
#  16  inning             3098 non-null   int64
#  17  inning_topbot      3098 non-null   object
#  18  stand              3098 non-null   object
#  19  p_throws           3098 non-null   object
#  20  bat_score          3098 non-null   int64
#  21  fld_score          3098 non-null   int64
#  22  at_bat_number      3098 non-null   int64
#  23  pitch_number       3098 non-null   int64
#  24  game_pk            3098 non-null   int64
#  25  batter             3098 non-null   int64
#  26  pitcher            3098 non-null   int64
#  27  description        3098 non-null   object
#  28  events             3098 non-null   object
# dtypes: float64(12), int64(11), object(6)
# memory usage: 702.0+ KB

# %% [markdown]
# # Cleaning and Feature Engineering
#
# Before fully cleaning, I wanted to do Exploratory Data Analysis to truly gain the full understanding of the data. I can now look into outliers, one-hot encode the data, and scale it. From there, I can do any more feature engineering I find necessary.

# %% [markdown]
# ## Outliers
#
# To deal with outliers, I will use the Inter-Quartile range, considering the outliers anything outside of the 1st and 3rd quartiles.
#
# The columns I am going to check outliers for are:
#
#
#
# *   Release_speed: Extreme values could be common
# *   Release positions: Could indicate data error, random unusual mechanics, or misclassification
# * Release Spin Rate and Axis: Tracking is a bit harder with spin, could be a tracking error.

# %%
columns_to_check = ['release_speed', 'release_pos_x', 'release_pos_z', 'release_pos_y', 'release_spin_rate', 'spin_axis']

def outliers (data, columns):
  for column in columns:
    q1 = data[column].quantile(0.25)
    q3 = data[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)
    data = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]
  return data

sale_outliers = outliers(sale, columns_to_check)
skubal_outliers = outliers(skubal, columns_to_check)

# %%
## Investigating Sale's Outliers
sale_outliers
# Out:
#      pitch_type  release_speed  release_pos_x  release_pos_y  release_pos_z  \
# 0            FF           93.5           3.24          53.82           5.29
# 1            FF           94.8           3.30          53.99           5.32
# 2            FF           93.7           3.43          53.88           5.23
# 3            FF           93.2           3.45          54.07           5.29
# 4            SL           78.3           3.54          54.40           5.11
# ...         ...            ...            ...            ...            ...
# 2810         FF           90.7           2.92          54.00           5.16
# 2811         SL           73.3           2.99          54.29           5.01
# 2812         FF           90.3           2.87          53.95           5.31
# 2813         FF           92.5           2.96          53.93           5.16
# 2814         SL           79.8           2.97          54.27           4.97
#
#       release_spin_rate  spin_axis  pfx_x  pfx_z  plate_x  ...  p_throws  \
# 0                  2192        114   1.21   0.78    -0.64  ...         L
# 1                  2289        121   1.23   1.21     0.23  ...         L
# 2                  2246        116   1.17   1.24     1.27  ...         L
# 3                  2186        119   1.08   1.06     0.88  ...         L
# 4                  2414        314  -1.33  -0.59    -0.65  ...         L
# ...                 ...        ...    ...    ...      ...  ...       ...
# 2810               2238        116   1.32   0.87    -0.67  ...         L
# 2811               2160        310  -0.84  -0.32     0.05  ...         L
# 2812               2132        116   1.13   1.06     0.82  ...         L
# 2813               2255        114   1.27   0.92     1.65  ...         L
# 2814               2285        314  -0.27  -0.02     0.15  ...         L
#
#       bat_score  fld_score  at_bat_number  pitch_number  game_pk  batter  \
# 0             0          2              6             1   745602  656941
# 1             0          2              6             2   745602  656941
# 2             1          2              7             1   745602  607208
# 3             1          2              7             2   745602  607208
# 4             1          2              7             3   745602  607208
# ...         ...        ...            ...           ...      ...     ...
# 2810          2          8             46             2   746663  668715
# 2811          2          8             46             3   746663  668715
# 2812          2          8             46             4   746663  668715
# 2813          2          8             46             5   746663  668715
# 2814          2          8             46             6   746663  668715
#
#      pitcher      description           events
# 0     519242    called_strike  batter still up
# 1     519242    hit_into_play         home_run
# 2     519242             ball  batter still up
# 3     519242    called_strike  batter still up
# 4     519242  swinging_strike  batter still up
# ...      ...              ...              ...
# 2810  519242             foul  batter still up
# 2811  519242             foul  batter still up
# 2812  519242             ball  batter still up
# 2813  519242             ball  batter still up
# 2814  519242         foul_tip        strikeout
#
# [2712 rows x 29 columns]

# %% [markdown]
# 2,712 out of 2,815 observations were considered outliers. Because of that, I am actually not going to delete any.

# %%
## Investigating Skubal's outliers
skubal_outliers
# Out:
#      pitch_type  release_speed  release_pos_x  release_pos_y  release_pos_z  \
# 0            FF           95.7           1.64          54.13           6.47
# 1            SI           94.5           1.95          54.13           6.30
# 2            SL           86.4           1.89          54.13           6.38
# 3            FF           96.1           1.81          54.14           6.36
# 4            FF           98.0           1.81          54.13           6.33
# ...         ...            ...            ...            ...            ...
# 3092         SL           87.3           1.58          54.02           6.21
# 3093         SL           86.3           1.51          54.11           6.29
# 3095         CH           87.3           1.33          54.17           6.28
# 3096         SI           96.1           1.28          54.08           6.31
# 3097         FF           95.7           1.33          54.18           6.33
#
#       release_spin_rate   spin_axis  pfx_x  pfx_z  plate_x  ...  p_throws  \
# 0           2228.775348  147.887674   0.71   1.47    -0.85  ...         L
# 1           2117.539634  146.057927   1.41   1.05     0.50  ...         L
# 2           2108.286682  164.611738  -0.12   0.48    -0.99  ...         L
# 3           2228.775348  147.887674   0.54   1.46    -0.43  ...         L
# 4           2228.775348  147.887674   0.81   1.38     0.33  ...         L
# ...                 ...         ...    ...    ...      ...  ...       ...
# 3092        2155.000000  163.000000  -0.31   0.63    -0.44  ...         L
# 3093        1976.000000  170.000000  -0.05   0.59     1.06  ...         L
# 3095        1619.000000  137.000000   1.09   0.48     0.04  ...         L
# 3096        1918.000000  157.000000   1.09   1.10     0.00  ...         L
# 3097        2278.000000  153.000000   0.40   1.42     0.67  ...         L
#
#       bat_score  fld_score  at_bat_number  pitch_number  game_pk  batter  \
# 0             0          0              4             1   746821  643217
# 1             0          0              4             2   746821  643217
# 2             0          0              4             3   746821  643217
# 3             0          0              4             4   746821  643217
# 4             0          0              4             5   746821  643217
# ...         ...        ...            ...           ...      ...     ...
# 3092          5          1             45             2   775326  678877
# 3093          5          2             53             1   775326  666310
# 3095          5          2             53             3   775326  666310
# 3096          5          2             54             1   775326  665926
# 3097          5          2             55             1   775326  677587
#
#      pitcher              description           events
# 0     669373                     ball  batter still up
# 1     669373                     foul  batter still up
# 2     669373                     ball  batter still up
# 3     669373          swinging_strike  batter still up
# 4     669373                     foul  batter still up
# ...      ...                      ...              ...
# 3092  669373            hit_into_play        field_out
# 3093  669373          swinging_strike  batter still up
# 3095  669373  swinging_strike_blocked        strikeout
# 3096  669373            hit_into_play        field_out
# 3097  669373            hit_into_play        field_out
#
# [2812 rows x 29 columns]

# %% [markdown]
# Again, 2,812 of Skubal's 3,098 pitches were marked as outliers. For the same reason as above, I am not going to delete any of these.

# %% [markdown]
# ## One-Hot Encoding
#
# RNNs require one-hot encoding to run because it expects numerical input. Any variable that is categorical will be one-hot encoded. It is especially important for the target variable: pitch_type.

# %%
columns_to_encode = ['pitch_type', 'inning_topbot', 'stand', 'p_throws']
def one_hot_encode (data, columns):
  for column in columns:
    data = pd.get_dummies(data, columns=[column], drop_first=True, dtype=int)
  return data

sale_encoded = one_hot_encode(sale, columns_to_encode)
skubal_encoded = one_hot_encode(skubal, columns_to_encode)

# %% [markdown]
# ## Sequence Commonality
#
# For modeling, all sequences need to be the same length. Because not every at-bat is the same, I need to do this manually. I will see how long at-bats are per pitcher and then remove any at-bats that aren't as long or remove pitches that go beyond this number.

# %%
def sequence_length(data):
  sequence_lengths = data.groupby('pitch_number')['pitch_number'].count()
  return sequence_lengths

sequence_length(sale_encoded)
# Out:
# pitch_number
# 1     702
# 2     631
# 3     533
# 4     410
# 5     286
# 6     135
# 7      70
# 8      31
# 9      11
# 10      5
# 11      1
# Name: pitch_number, dtype: int64

# %% [markdown]
# We see the biggest drop off between 4 and 5 pitches and 5 and 6 pitches. I think for this, I want to stick to 4 pitches. Having 410 sequences to train on is much better than 286 or 135. Using 4 pitches balances having enough data and enough predictive power. Because this is just immediate predictions, I do not need longer sequences.

# %%
## Getting all the sequences to be length 4, and dropping the sequences that do not have 4 pitches
sale_encoded = sale_encoded[sale_encoded['pitch_number'] <= 4]

def short_sequences(data, pitch_num):
    sequences = data.groupby(['game_pk', 'at_bat_number'])['pitch_number'].count()

    # Filter to only keep combinations where the number of pitches is exactly 4
    valid_combinations = sequences[sequences == pitch_num]

    # Filter the original data to keep only the rows with these valid combinations
    filtered_data = data[data.set_index(['game_pk', 'at_bat_number']).index.isin(valid_combinations.index)]

    return filtered_data


sale_seq = short_sequences(sale_encoded, 4)

# %% [markdown]
# Doing the same for Tarik Skubal.

# %%
sequence_length(skubal_encoded)
# Out:
# pitch_number
# 1     819
# 2     734
# 3     605
# 4     437
# 5     271
# 6     140
# 7      55
# 8      24
# 9       9
# 10      3
# 11      1
# Name: pitch_number, dtype: int64

# %% [markdown]
# 4 also seems to be the best number here.

# %%
skubal_seq = short_sequences(skubal_encoded, 4)

# %% [markdown]
# ## Extra Variables
#
# There were some variables that were included for ease of EDA that aren't needed when actually modeling. These are variables that do not effect the sequence of the pitch and what happens, like variables that identify the game, but not the actual state of the game.
#
# The dropped variables include:
#
# * game_pk
# * batter
# * pitcher (we know who it is)
# * at_bat_number
# * bat_score
# * fld_score
# * events (data leakage)
# * description (potential data leakage)

# %%
columns_to_drop = ['game_pk', 'batter', 'pitcher', 'at_bat_number', 'bat_score', 'fld_score', 'events', 'description']

sale_cleaned = sale_seq.drop(columns=columns_to_drop)
skubal_cleaned = skubal_seq.drop(columns=columns_to_drop)

# %% [markdown]
# ## Normalizing Data
#
# Normalizing/Scaling the data is important for RNNs for multiple reasons. It helps with efficiency, activation functions, and vanishing and exploding gradients. I am choosing to use the standard scaler based on personal preference of what I have felt works best in my past experience.
#
# Note: I will not be normalizing pitch_number, as it represents the sequence number that I will later be testing.

# %%
## Initializing Scaler
scaler = StandardScaler()

## Separating 'pitch_number'
sale_pitch_number = sale_cleaned['pitch_number']
skubal_pitch_number = skubal_cleaned['pitch_number']

## Applying Scaler (excluding 'pitch_number')
sale_scaled = scaler.fit_transform(sale_cleaned.drop(columns=['pitch_number']))
skubal_scaled = scaler.fit_transform(skubal_cleaned.drop(columns=['pitch_number']))

## Back to a DataFrame and Reattach 'pitch_number'
sale_scaled = pd.DataFrame(sale_scaled, columns=sale_cleaned.columns.drop('pitch_number'))
skubal_scaled = pd.DataFrame(skubal_scaled, columns=skubal_cleaned.columns.drop('pitch_number'))

sale_scaled['pitch_number'] = sale_pitch_number.values
skubal_scaled['pitch_number'] = skubal_pitch_number.values

# %%
sale_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1632 entries, 0 to 1631
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_speed      1632 non-null   float64
#  1   release_pos_x      1632 non-null   float64
#  2   release_pos_y      1632 non-null   float64
#  3   release_pos_z      1632 non-null   float64
#  4   release_spin_rate  1632 non-null   float64
#  5   spin_axis          1632 non-null   float64
#  6   pfx_x              1632 non-null   float64
#  7   pfx_z              1632 non-null   float64
#  8   plate_x            1632 non-null   float64
#  9   plate_z            1632 non-null   float64
#  10  sz_top             1632 non-null   float64
#  11  sz_bot             1632 non-null   float64
#  12  balls              1632 non-null   float64
#  13  strikes            1632 non-null   float64
#  14  outs_when_up       1632 non-null   float64
#  15  inning             1632 non-null   float64
#  16  pitch_type_FF      1632 non-null   float64
#  17  pitch_type_SI      1632 non-null   float64
#  18  pitch_type_SL      1632 non-null   float64
#  19  inning_topbot_Top  1632 non-null   float64
#  20  stand_R            1632 non-null   float64
#  21  pitch_number       1632 non-null   int64
# dtypes: float64(21), int64(1)
# memory usage: 280.6 KB

# %%
skubal_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3098 entries, 0 to 3097
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_speed      3098 non-null   float64
#  1   release_pos_x      3098 non-null   float64
#  2   release_pos_y      3098 non-null   float64
#  3   release_pos_z      3098 non-null   float64
#  4   release_spin_rate  3098 non-null   float64
#  5   spin_axis          3098 non-null   float64
#  6   pfx_x              3098 non-null   float64
#  7   pfx_z              3098 non-null   float64
#  8   plate_x            3098 non-null   float64
#  9   plate_z            3098 non-null   float64
#  10  sz_top             3098 non-null   float64
#  11  sz_bot             3098 non-null   float64
#  12  balls              3098 non-null   float64
#  13  strikes            3098 non-null   float64
#  14  outs_when_up       3098 non-null   float64
#  15  inning             3098 non-null   float64
#  16  pitch_type_FF      3098 non-null   float64
#  17  pitch_type_KC      3098 non-null   float64
#  18  pitch_type_SI      3098 non-null   float64
#  19  pitch_type_SL      3098 non-null   float64
#  20  inning_topbot_Top  3098 non-null   float64
#  21  stand_R            3098 non-null   float64
#  22  pitch_number       3098 non-null   int64
# dtypes: float64(22), int64(1)
# memory usage: 556.8 KB

# %% [markdown]
# ## Final Important Step
#
# Each sequence (1, 2, 3, 4) need a unique identifier for modeling. So, I need to add a column, seq_id, that does this.

# %%
def add_seq_id(data):
  seq_id = 1
  data['seq_id'] = 0

  for i in range(len(data)):
    if i % 4 == 0:
      data.loc[i, 'seq_id'] = seq_id
      seq_id += 1
    else:
      data.loc[i, 'seq_id'] = seq_id - 1
  return data

sale_scaled = add_seq_id(sale_scaled)
skubal_scaled = add_seq_id(skubal_scaled)

# %% [markdown]
# # What's Next?
#
# Yay! The data is finally ready to be modeled! We encoded the variables, "dealt" with outliers, and normalized the data. I want to note that I choose to not perform Principal Component Analysis. With only 19 predictor variables, PCA is not necessary.
#
# Now that the data is ready...
#
#
# *   RNN Modeling
#   * Hyperparameter Tuning
#   * Model Validation and Evaluation
#   * Model Comparison

# %%
## Printing the readied data to .csvs

sale_scaled.to_csv('sale_modeling.csv', index=False)
skubal_scaled.to_csv('skubal_modeling.csv', index=False)
