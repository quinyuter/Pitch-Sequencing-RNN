# %%
#!pip install pybaseball
# Out:
# Collecting pybaseball
#   Downloading pybaseball-2.2.7-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (2.0.2)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (2.2.2)
# Requirement already satisfied: beautifulsoup4>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (4.13.3)
# Requirement already satisfied: requests>=2.18.1 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (2.32.3)
# Requirement already satisfied: lxml>=4.2.1 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (5.3.1)
# Requirement already satisfied: pyarrow>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (18.1.0)
# Collecting pygithub>=1.51 (from pybaseball)
#   Downloading PyGithub-2.6.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (1.14.1)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (3.10.0)
# Requirement already satisfied: tqdm>=4.50.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (4.67.1)
# Requirement already satisfied: attrs>=20.3.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (25.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.0->pybaseball) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.0->pybaseball) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.3->pybaseball) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.3->pybaseball) (2025.1)
# Collecting pynacl>=1.4.0 (from pygithub>=1.51->pybaseball)
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (2.10.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from pygithub>=1.51->pybaseball) (2.3.0)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.11/dist-packages (from pygithub>=1.51->pybaseball) (1.2.18)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.1->pybaseball) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.1->pybaseball) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.1->pybaseball) (2025.1.31)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (43.0.3)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pynacl>=1.4.0->pygithub>=1.51->pybaseball) (1.17.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pybaseball) (1.17.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated->pygithub>=1.51->pybaseball) (1.17.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub>=1.51->pybaseball) (2.22)
# Downloading pybaseball-2.2.7-py3-none-any.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.1/426.1 kB 4.5 MB/s eta 0:00:00
# Downloading PyGithub-2.6.1-py3-none-any.whl (410 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 14.6 MB/s eta 0:00:00
# Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 25.8 MB/s eta 0:00:00
# Installing collected packages: pynacl, pygithub, pybaseball
# Successfully installed pybaseball-2.2.7 pygithub-2.6.1 pynacl-1.5.0

# %% [markdown]
# https://github.com/jldbc/pybaseball

# %%
from pybaseball import  playerid_lookup
from pybaseball import  statcast_pitcher
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading in data

# %%
## Grabbing Chris Sale and Tarik Skubal
pd.concat([playerid_lookup('sale', 'chris'), playerid_lookup('skubal', 'tarik')])
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0      sale      chris     519242  salec001   salech01          10603
# 0    skubal      tarik     669373  skubt001  skubata01          22267
#
#    mlb_played_first  mlb_played_last
# 0            2010.0           2024.0
# 0            2020.0           2024.0

# %%
## Putting their pitch by pitch data into a data frame
sale_2024 = statcast_pitcher('2024-03-28', '2024-11-02', 519242)
skubal_2024 = statcast_pitcher('2024-03-28', '2024-11-02', 669373)
# Out:
# Gathering Player Data
# Gathering Player Data

# %% [markdown]
# The columns go from most recent to least recent. I want this order to be switched, since I am looking to sequence from beginning to end, not vise versa.

# %%
sale_2024 = sale_2024.iloc[::-1].reset_index(drop=True)
skubal_2024 = skubal_2024.iloc[::-1].reset_index(drop=True)

# %% [markdown]
# # Column Cleaning
#
# Many of these columns are not important, let's explore this deeper. I will drop all columns not necessary for this project.

# %%
print(sale_2024.columns.tolist())
# Out:
# ['pitch_type', 'game_date', 'release_speed', 'release_pos_x', 'release_pos_z', 'player_name', 'batter', 'pitcher', 'events', 'description', 'spin_dir', 'spin_rate_deprecated', 'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des', 'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type', 'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x', 'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y', 'tfs_deprecated', 'tfs_zulu_deprecated', 'umpire', 'sv_id', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot', 'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed', 'release_spin_rate', 'release_extension', 'game_pk', 'fielder_2', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8', 'fielder_9', 'release_pos_y', 'estimated_ba_using_speedangle', 'estimated_woba_using_speedangle', 'woba_value', 'woba_denom', 'babip_value', 'iso_value', 'launch_speed_angle', 'at_bat_number', 'pitch_number', 'pitch_name', 'home_score', 'away_score', 'bat_score', 'fld_score', 'post_away_score', 'post_home_score', 'post_bat_score', 'post_fld_score', 'if_fielding_alignment', 'of_fielding_alignment', 'spin_axis', 'delta_home_win_exp', 'delta_run_exp', 'bat_speed', 'swing_length', 'estimated_slg_using_speedangle', 'delta_pitcher_run_exp', 'hyper_speed', 'home_score_diff', 'bat_score_diff', 'home_win_exp', 'bat_win_exp', 'age_pit_legacy', 'age_bat_legacy', 'age_pit', 'age_bat', 'n_thruorder_pitcher', 'n_priorpa_thisgame_player_at_bat', 'pitcher_days_since_prev_game', 'batter_days_since_prev_game', 'pitcher_days_until_next_game', 'batter_days_until_next_game', 'api_break_z_with_gravity', 'api_break_x_arm', 'api_break_x_batter_in', 'arm_angle']

# %%
columns_to_keep = [
    'pitch_type', 'release_speed', 'release_pos_x', 'release_pos_y', 'release_pos_z',
    'release_spin_rate', 'spin_axis', 'pfx_x', 'pfx_z', 'plate_x', 'plate_z', 'sz_top', 'sz_bot',
    'balls', 'strikes', 'outs_when_up', 'inning', 'inning_topbot', 'stand', 'p_throws',
    'bat_score', 'fld_score', 'at_bat_number', 'pitch_number', 'game_pk', 'batter', 'pitcher',
    'description', 'events'
]

sale_2024 = sale_2024[columns_to_keep]
skubal_2024 = skubal_2024[columns_to_keep]

# %% [markdown]
# # Why did I drop all other columns?
#
# * **fielder_2 ... fielder_9**: Do not need to know who the others on the field are
# * **if_fielding_alignment, of_fielding_alignment:** Is not related to pitch sequencing
# * **hit_location, hit_distance_sc, launch_speed, launch_angle, launch_speed_angle, estimated_ba_using_speedangle, estimated_woba_using_speedangle, woba_value, woba_denom, babip_value, iso_value, estimated_slg_using_speedangle, post_away_score, post_home_score, post_bat_score, post_fld_score, delta_home_win_exp, delta_run_exp, delta_pitcher_run_exp, home_score_diff, bat_score_diff, home_win_exp, bat_win_exp:** These are all about what happens after the pitch was thrown. This could bring risk of data leakage, because it is future information that an RNN should not have access to. They also do not have anything to do with the actual pitch sequence.
# * **tfs_deprecated, tfs_zulu_deprecated, umpire, game_year, hc_x, hc_y:** These metrics are redundant, as they either add value that doesn't matter or they add value that is already found elsewhere in the data.
# * **age_bat_legacy, age_pit_legacy, age_bat, n_priorpa_thisgame_player_at_bat, batter_days_since_prev_game, pitcher_days_until_next_game, batter_days_until_next_game:** This is more batter and pitcher historical data. They describe historical (or future) performance rather than real-time sequencing in games. While this is sometimes important in order to understand performance, they are noise when it comes to using RNNs.
#
# # Why did I keep these columns?
#
# The columns I kept define the game state, pitch characteristics, and context necessary for sequencing. For example, pitch_type, release_speed, and the other pitcher metrics describe what the pitcher does (and really who they are as a pitcher). Game context (like balls, strikes, and inning) are important because they affect decision making. The rest of the columns kept are necessary to sequence the data.

# %% [markdown]
# # Missing Data
#
# Now that the columns are the ones we want, I am going to explore if there are missing data in these columns, and what to do about it.

# %%
pd.DataFrame({
    'sale_2024_missing': sale_2024.isna().sum(),
    'skubal_2024_missing': skubal_2024.isna().sum()
})
# Out:
#                    sale_2024_missing  skubal_2024_missing
# pitch_type                         0                   28
# release_speed                      0                   28
# release_pos_x                      0                   28
# release_pos_y                      0                   28
# release_pos_z                      0                   28
# release_spin_rate                  0                   55
# spin_axis                          0                   55
# pfx_x                              0                   28
# pfx_z                              0                   28
# plate_x                            0                   28
# plate_z                            0                   28
# sz_top                             0                   28
# sz_bot                             0                   28
# balls                              0                    0
# strikes                            0                    0
# outs_when_up                       0                    0
# inning                             0                    0
# inning_topbot                      0                    0
# stand                              0                    0
# p_throws                           0                    0
# bat_score                          0                    0
# fld_score                          0                    0
# at_bat_number                      0                    0
# pitch_number                       0                    0
# game_pk                            0                    0
# batter                             0                    0
# pitcher                            0                    0
# description                        0                    0
# events                          2112                 2304

# %% [markdown]
# This is interesting. The only column that sale has missing data in is "events", while Skubal has some in many other columns. The tricky part about dealing with missing data in this case is that it is sequenced. That is, I can't just remove rows with missing data because that messes up the sequence of it all.
#
# With "events", NA makes sense, as the event column is only filled when the at-bat is up. I will impute these rows with "batter still up" as a place holder. After this is done, I will do some more deep exploring into what the reason is behind these missing values.

# %%
## Imputing missing values in the 'events' column with 'batter still up'
sale_2024['events'] = sale_2024['events'].fillna('batter still up')
skubal_2024['events'] = skubal_2024['events'].fillna('batter still up')

# %% [markdown]
# Let's look into Skubal's rows with missing data.

# %%
skubal_2024[skubal_2024.isna().any(axis=1)]
# Out:
#      pitch_type  release_speed  release_pos_x  release_pos_y  release_pos_z  \
# 0            FF           95.7           1.64          54.13           6.47
# 1            SI           94.5           1.95          54.13           6.30
# 2            SL           86.4           1.89          54.13           6.38
# 3            FF           96.1           1.81          54.14           6.36
# 4            FF           98.0           1.81          54.13           6.33
# 5            SI           96.4           1.93          54.13           6.24
# 6            SL           87.6           2.10          54.13           6.26
# 7            FF           97.4           1.75          54.13           6.40
# 8            CH           86.0           1.77          54.13           6.32
# 9            CH           86.0           1.61          54.13           6.36
# 10           FF           95.7           1.74          54.13           6.34
# 11           SI           94.9           1.74          54.13           6.36
# 12           CH           84.5           1.57          54.13           6.39
# 13           FF           96.3           1.73          54.13           6.41
# 14           FF           95.2           1.74          54.13           6.31
# 15           CH           85.1           1.83          54.13           6.32
# 16           FF           95.8           1.64          54.13           6.37
# 17           FF           95.4           1.89          54.13           6.27
# 18           CH           85.2           1.56          54.13           6.40
# 19           CH           83.3           1.79          54.13           6.34
# 20           SI           96.4           1.67          54.14           6.33
# 21           SI           93.8           1.95          54.13           6.17
# 22           SL           87.9           2.22          54.13           6.24
# 23           SI           95.6           1.69          54.13           6.32
# 24           CH           83.5           1.67          54.38           6.45
# 25           FF           94.6           1.71          54.09           6.34
# 157          SL           83.2           1.61          54.29           6.09
# 2202        NaN            NaN            NaN            NaN            NaN
# 2203        NaN            NaN            NaN            NaN            NaN
# 2204        NaN            NaN            NaN            NaN            NaN
# 2205        NaN            NaN            NaN            NaN            NaN
# 2206        NaN            NaN            NaN            NaN            NaN
# 2207        NaN            NaN            NaN            NaN            NaN
# 2208        NaN            NaN            NaN            NaN            NaN
# 2209        NaN            NaN            NaN            NaN            NaN
# 2210        NaN            NaN            NaN            NaN            NaN
# 2211        NaN            NaN            NaN            NaN            NaN
# 2212        NaN            NaN            NaN            NaN            NaN
# 2213        NaN            NaN            NaN            NaN            NaN
# 2214        NaN            NaN            NaN            NaN            NaN
# 2215        NaN            NaN            NaN            NaN            NaN
# 2216        NaN            NaN            NaN            NaN            NaN
# 2217        NaN            NaN            NaN            NaN            NaN
# 2218        NaN            NaN            NaN            NaN            NaN
# 2219        NaN            NaN            NaN            NaN            NaN
# 2220        NaN            NaN            NaN            NaN            NaN
# 2221        NaN            NaN            NaN            NaN            NaN
# 2222        NaN            NaN            NaN            NaN            NaN
# 2223        NaN            NaN            NaN            NaN            NaN
# 2224        NaN            NaN            NaN            NaN            NaN
# 2225        NaN            NaN            NaN            NaN            NaN
# 2226        NaN            NaN            NaN            NaN            NaN
# 2227        NaN            NaN            NaN            NaN            NaN
# 2228        NaN            NaN            NaN            NaN            NaN
# 2229        NaN            NaN            NaN            NaN            NaN
#
#       release_spin_rate  spin_axis  pfx_x  pfx_z  plate_x  plate_z  sz_top  \
# 0                   NaN        NaN   0.71   1.47    -0.85     3.61    3.31
# 1                   NaN        NaN   1.41   1.05     0.50     2.61    3.27
# 2                   NaN        NaN  -0.12   0.48    -0.99     2.63    3.35
# 3                   NaN        NaN   0.54   1.46    -0.43     2.47    3.27
# 4                   NaN        NaN   0.81   1.38     0.33     3.01    3.27
# 5                   NaN        NaN   1.41   1.14     0.47     3.97    3.27
# 6                   NaN        NaN  -0.26   0.35    -1.05     1.20    3.27
# 7                   NaN        NaN   0.50   1.26     0.08     3.53    3.31
# 8                   NaN        NaN   1.19   0.68    -0.38     2.81    3.78
# 9                   NaN        NaN   1.28   0.36    -0.12     2.04    3.74
# 10                  NaN        NaN   0.72   1.53     0.01     3.64    3.41
# 11                  NaN        NaN   1.23   0.84    -1.08     4.27    3.65
# 12                  NaN        NaN   1.41   0.55    -0.09     1.58    3.55
# 13                  NaN        NaN   0.56   1.73    -0.90     3.94    3.41
# 14                  NaN        NaN   0.79   1.42    -1.79     1.76    3.40
# 15                  NaN        NaN   1.38   0.39    -1.31     2.35    3.43
# 16                  NaN        NaN   0.70   1.57    -0.25     2.12    3.33
# 17                  NaN        NaN   0.86   1.54    -0.60     2.31    3.44
# 18                  NaN        NaN   1.59   0.64    -0.60    -0.24    3.43
# 19                  NaN        NaN   1.34   0.58    -0.73     3.19    3.37
# 20                  NaN        NaN   1.25   1.31    -0.61     3.45    3.44
# 21                  NaN        NaN   1.38   1.16    -0.17     3.15    3.35
# 22                  NaN        NaN  -0.37   0.37     0.81     3.83    3.29
# 23                  NaN        NaN   1.39   1.02    -1.04     2.57    3.28
# 24                  NaN        NaN   1.22   0.46    -0.03     4.94    3.28
# 25                  NaN        NaN   0.90   1.46    -0.16     2.88    3.27
# 157                 NaN        NaN   0.23   1.40    -0.22     2.74    3.29
# 2202                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2203                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2204                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2205                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2206                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2207                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2208                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2209                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2210                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2211                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2212                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2213                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2214                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2215                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2216                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2217                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2218                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2219                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2220                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2221                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2222                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2223                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2224                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2225                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2226                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2227                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2228                NaN        NaN    NaN    NaN      NaN      NaN     NaN
# 2229                NaN        NaN    NaN    NaN      NaN      NaN     NaN
#
#       sz_bot  balls  strikes  outs_when_up  inning inning_topbot stand  \
# 0       1.54      0        0             0       1           Bot     L
# 1       1.51      1        0             0       1           Bot     L
# 2       1.53      1        1             0       1           Bot     L
# 3       1.51      2        1             0       1           Bot     L
# 4       1.51      2        2             0       1           Bot     L
# 5       1.51      2        2             0       1           Bot     L
# 6       1.51      2        2             0       1           Bot     L
# 7       1.47      0        0             1       1           Bot     R
# 8       1.78      0        0             2       1           Bot     R
# 9       1.77      0        1             2       1           Bot     R
# 10      1.64      0        0             2       1           Bot     R
# 11      1.72      0        1             2       1           Bot     R
# 12      1.72      1        1             2       1           Bot     R
# 13      1.64      2        1             2       1           Bot     R
# 14      1.61      0        0             0       2           Bot     R
# 15      1.62      1        0             0       2           Bot     R
# 16      1.58      2        0             0       2           Bot     R
# 17      1.57      0        0             0       2           Bot     R
# 18      1.57      0        1             0       2           Bot     R
# 19      1.49      1        1             0       2           Bot     R
# 20      1.57      1        2             0       2           Bot     R
# 21      1.54      0        0             1       2           Bot     R
# 22      1.54      0        1             1       2           Bot     R
# 23      1.56      1        1             1       2           Bot     R
# 24      1.56      2        1             1       2           Bot     R
# 25      1.58      3        1             1       2           Bot     R
# 157     1.51      0        1             2       6           Top     R
# 2202     NaN      0        0             0       1           Top     R
# 2203     NaN      0        1             0       1           Top     R
# 2204     NaN      1        1             0       1           Top     R
# 2205     NaN      1        2             0       1           Top     R
# 2206     NaN      1        2             0       1           Top     R
# 2207     NaN      2        2             0       1           Top     R
# 2208     NaN      3        2             0       1           Top     R
# 2209     NaN      3        2             0       1           Top     R
# 2210     NaN      0        0             1       1           Top     L
# 2211     NaN      0        1             1       1           Top     L
# 2212     NaN      1        1             1       1           Top     L
# 2213     NaN      0        0             2       1           Top     R
# 2214     NaN      0        1             2       1           Top     R
# 2215     NaN      0        2             2       1           Top     R
# 2216     NaN      0        0             0       2           Top     R
# 2217     NaN      0        1             0       2           Top     R
# 2218     NaN      0        0             0       2           Top     R
# 2219     NaN      1        0             0       2           Top     R
# 2220     NaN      1        1             0       2           Top     R
# 2221     NaN      1        2             0       2           Top     R
# 2222     NaN      2        2             0       2           Top     R
# 2223     NaN      2        2             0       2           Top     R
# 2224     NaN      0        0             1       2           Top     R
# 2225     NaN      1        0             1       2           Top     R
# 2226     NaN      1        1             1       2           Top     R
# 2227     NaN      1        2             1       2           Top     R
# 2228     NaN      2        2             1       2           Top     R
# 2229     NaN      2        2             1       2           Top     R
#
#      p_throws  bat_score  fld_score  at_bat_number  pitch_number  game_pk  \
# 0           L          0          0              4             1   746821
# 1           L          0          0              4             2   746821
# 2           L          0          0              4             3   746821
# 3           L          0          0              4             4   746821
# 4           L          0          0              4             5   746821
# 5           L          0          0              4             6   746821
# 6           L          0          0              4             7   746821
# 7           L          0          0              5             1   746821
# 8           L          0          0              6             1   746821
# 9           L          0          0              6             2   746821
# 10          L          0          0              7             1   746821
# 11          L          0          0              7             2   746821
# 12          L          0          0              7             3   746821
# 13          L          0          0              7             4   746821
# 14          L          0          0             12             1   746821
# 15          L          0          0             12             2   746821
# 16          L          0          0             12             3   746821
# 17          L          0          0             13             1   746821
# 18          L          0          0             13             2   746821
# 19          L          0          0             13             3   746821
# 20          L          0          0             13             4   746821
# 21          L          0          0             14             1   746821
# 22          L          0          0             14             2   746821
# 23          L          0          0             14             3   746821
# 24          L          0          0             14             4   746821
# 25          L          0          0             14             5   746821
# 157         L          2          3             42             2   746497
# 2202        L          0          0              1             1   746431
# 2203        L          0          0              1             2   746431
# 2204        L          0          0              1             3   746431
# 2205        L          0          0              1             4   746431
# 2206        L          0          0              1             5   746431
# 2207        L          0          0              1             6   746431
# 2208        L          0          0              1             7   746431
# 2209        L          0          0              1             8   746431
# 2210        L          0          0              2             1   746431
# 2211        L          0          0              2             2   746431
# 2212        L          0          0              2             3   746431
# 2213        L          0          0              3             1   746431
# 2214        L          0          0              3             2   746431
# 2215        L          0          0              3             3   746431
# 2216        L          0          0              7             1   746431
# 2217        L          0          0              7             2   746431
# 2218        L          0          0              8             1   746431
# 2219        L          0          0              8             2   746431
# 2220        L          0          0              8             3   746431
# 2221        L          0          0              8             4   746431
# 2222        L          0          0              8             5   746431
# 2223        L          0          0              8             6   746431
# 2224        L          0          0              9             1   746431
# 2225        L          0          0              9             2   746431
# 2226        L          0          0              9             3   746431
# 2227        L          0          0              9             4   746431
# 2228        L          0          0              9             5   746431
# 2229        L          0          0              9             6   746431
#
#       batter  pitcher      description           events
# 0     643217   669373             ball  batter still up
# 1     643217   669373             foul  batter still up
# 2     643217   669373             ball  batter still up
# 3     643217   669373  swinging_strike  batter still up
# 4     643217   669373             foul  batter still up
# 5     643217   669373             foul  batter still up
# 6     643217   669373  swinging_strike        strikeout
# 7     660162   669373    hit_into_play        field_out
# 8     673357   669373    called_strike  batter still up
# 9     673357   669373    hit_into_play           single
# 10    650391   669373         foul_tip  batter still up
# 11    650391   669373             ball  batter still up
# 12    650391   669373             ball  batter still up
# 13    650391   669373    hit_into_play        field_out
# 14    683734   669373             ball  batter still up
# 15    683734   669373             ball  batter still up
# 16    683734   669373    hit_into_play           single
# 17    657557   669373         foul_tip  batter still up
# 18    657557   669373     blocked_ball  batter still up
# 19    657557   669373    called_strike  batter still up
# 20    657557   669373  swinging_strike        strikeout
# 21    607680   669373    called_strike  batter still up
# 22    607680   669373             ball  batter still up
# 23    607680   669373             ball  batter still up
# 24    607680   669373             ball  batter still up
# 25    607680   669373             foul  batter still up
# 157   669127   669373             foul  batter still up
# 2202  650402   669373             foul  batter still up
# 2203  650402   669373             ball  batter still up
# 2204  650402   669373  swinging_strike  batter still up
# 2205  650402   669373             foul  batter still up
# 2206  650402   669373             ball  batter still up
# 2207  650402   669373             ball  batter still up
# 2208  650402   669373             foul  batter still up
# 2209  650402   669373    hit_into_play        field_out
# 2210  665742   669373    called_strike  batter still up
# 2211  665742   669373             ball  batter still up
# 2212  665742   669373    hit_into_play        field_out
# 2213  592450   669373    called_strike  batter still up
# 2214  592450   669373             foul  batter still up
# 2215  592450   669373  swinging_strike        strikeout
# 2216  519317   669373         foul_tip  batter still up
# 2217  519317   669373    hit_into_play           single
# 2218  691176   669373             ball  batter still up
# 2219  691176   669373             foul  batter still up
# 2220  691176   669373  swinging_strike  batter still up
# 2221  691176   669373             ball  batter still up
# 2222  691176   669373             foul  batter still up
# 2223  691176   669373    called_strike        strikeout
# 2224  624431   669373             ball  batter still up
# 2225  624431   669373  swinging_strike  batter still up
# 2226  624431   669373  swinging_strike  batter still up
# 2227  624431   669373             ball  batter still up
# 2228  624431   669373             foul  batter still up
# 2229  624431   669373             foul  batter still up

# %% [markdown]
# I am going to approach this in two ways: for the rows that are missing pitch type, I will just delete the sequence that it is in. For the rows that have pitch type, but are missing the other columns, I will impute the missing values with the average of that metric based on the given pitch. Release rate and spin axis change based on the type of pitch, which is why I think it is appropriate to approach it like this.

# %%
def find_missing_pitch_type_combinations(df, at_bat_col='at_bat_number', game_pk_col='game_pk', pitch_type_col='pitch_type'):

    nan_pitch_type_rows = df[df[pitch_type_col].isna()]
    return nan_pitch_type_rows[[at_bat_col, game_pk_col]].drop_duplicates()


missing_combinations = find_missing_pitch_type_combinations(skubal_2024)
missing_combinations
# Out:
#       at_bat_number  game_pk
# 2202              1   746431
# 2210              2   746431
# 2213              3   746431
# 2216              7   746431
# 2218              8   746431
# 2224              9   746431

# %% [markdown]
# Now that I know that these are the at_bat_number and game_pk combinations that have missing. I need to remove these entire at-bats to make sure that the sequences are still in tact. To do so, I will loop through this data frame and delete combinations in the actual skubal data frame.

# %%
for index, row in missing_combinations.iterrows():
    at_bat = row['at_bat_number']
    game_pk = row['game_pk']

    ## Creating a boolean mask for rows to delete
    mask = (skubal_2024['at_bat_number'] == at_bat) & (skubal_2024['game_pk'] == game_pk)

    ## Deleting the matching rows
    skubal_2024 = skubal_2024[~mask]

# %% [markdown]
# Let's check to see if this worked.

# %%
skubal_2024[skubal_2024.isna().any(axis=1)]
# Out:
#     pitch_type  release_speed  release_pos_x  release_pos_y  release_pos_z  \
# 0           FF           95.7           1.64          54.13           6.47
# 1           SI           94.5           1.95          54.13           6.30
# 2           SL           86.4           1.89          54.13           6.38
# 3           FF           96.1           1.81          54.14           6.36
# 4           FF           98.0           1.81          54.13           6.33
# 5           SI           96.4           1.93          54.13           6.24
# 6           SL           87.6           2.10          54.13           6.26
# 7           FF           97.4           1.75          54.13           6.40
# 8           CH           86.0           1.77          54.13           6.32
# 9           CH           86.0           1.61          54.13           6.36
# 10          FF           95.7           1.74          54.13           6.34
# 11          SI           94.9           1.74          54.13           6.36
# 12          CH           84.5           1.57          54.13           6.39
# 13          FF           96.3           1.73          54.13           6.41
# 14          FF           95.2           1.74          54.13           6.31
# 15          CH           85.1           1.83          54.13           6.32
# 16          FF           95.8           1.64          54.13           6.37
# 17          FF           95.4           1.89          54.13           6.27
# 18          CH           85.2           1.56          54.13           6.40
# 19          CH           83.3           1.79          54.13           6.34
# 20          SI           96.4           1.67          54.14           6.33
# 21          SI           93.8           1.95          54.13           6.17
# 22          SL           87.9           2.22          54.13           6.24
# 23          SI           95.6           1.69          54.13           6.32
# 24          CH           83.5           1.67          54.38           6.45
# 25          FF           94.6           1.71          54.09           6.34
# 157         SL           83.2           1.61          54.29           6.09
#
#      release_spin_rate  spin_axis  pfx_x  pfx_z  plate_x  plate_z  sz_top  \
# 0                  NaN        NaN   0.71   1.47    -0.85     3.61    3.31
# 1                  NaN        NaN   1.41   1.05     0.50     2.61    3.27
# 2                  NaN        NaN  -0.12   0.48    -0.99     2.63    3.35
# 3                  NaN        NaN   0.54   1.46    -0.43     2.47    3.27
# 4                  NaN        NaN   0.81   1.38     0.33     3.01    3.27
# 5                  NaN        NaN   1.41   1.14     0.47     3.97    3.27
# 6                  NaN        NaN  -0.26   0.35    -1.05     1.20    3.27
# 7                  NaN        NaN   0.50   1.26     0.08     3.53    3.31
# 8                  NaN        NaN   1.19   0.68    -0.38     2.81    3.78
# 9                  NaN        NaN   1.28   0.36    -0.12     2.04    3.74
# 10                 NaN        NaN   0.72   1.53     0.01     3.64    3.41
# 11                 NaN        NaN   1.23   0.84    -1.08     4.27    3.65
# 12                 NaN        NaN   1.41   0.55    -0.09     1.58    3.55
# 13                 NaN        NaN   0.56   1.73    -0.90     3.94    3.41
# 14                 NaN        NaN   0.79   1.42    -1.79     1.76    3.40
# 15                 NaN        NaN   1.38   0.39    -1.31     2.35    3.43
# 16                 NaN        NaN   0.70   1.57    -0.25     2.12    3.33
# 17                 NaN        NaN   0.86   1.54    -0.60     2.31    3.44
# 18                 NaN        NaN   1.59   0.64    -0.60    -0.24    3.43
# 19                 NaN        NaN   1.34   0.58    -0.73     3.19    3.37
# 20                 NaN        NaN   1.25   1.31    -0.61     3.45    3.44
# 21                 NaN        NaN   1.38   1.16    -0.17     3.15    3.35
# 22                 NaN        NaN  -0.37   0.37     0.81     3.83    3.29
# 23                 NaN        NaN   1.39   1.02    -1.04     2.57    3.28
# 24                 NaN        NaN   1.22   0.46    -0.03     4.94    3.28
# 25                 NaN        NaN   0.90   1.46    -0.16     2.88    3.27
# 157                NaN        NaN   0.23   1.40    -0.22     2.74    3.29
#
#      sz_bot  balls  strikes  outs_when_up  inning inning_topbot stand  \
# 0      1.54      0        0             0       1           Bot     L
# 1      1.51      1        0             0       1           Bot     L
# 2      1.53      1        1             0       1           Bot     L
# 3      1.51      2        1             0       1           Bot     L
# 4      1.51      2        2             0       1           Bot     L
# 5      1.51      2        2             0       1           Bot     L
# 6      1.51      2        2             0       1           Bot     L
# 7      1.47      0        0             1       1           Bot     R
# 8      1.78      0        0             2       1           Bot     R
# 9      1.77      0        1             2       1           Bot     R
# 10     1.64      0        0             2       1           Bot     R
# 11     1.72      0        1             2       1           Bot     R
# 12     1.72      1        1             2       1           Bot     R
# 13     1.64      2        1             2       1           Bot     R
# 14     1.61      0        0             0       2           Bot     R
# 15     1.62      1        0             0       2           Bot     R
# 16     1.58      2        0             0       2           Bot     R
# 17     1.57      0        0             0       2           Bot     R
# 18     1.57      0        1             0       2           Bot     R
# 19     1.49      1        1             0       2           Bot     R
# 20     1.57      1        2             0       2           Bot     R
# 21     1.54      0        0             1       2           Bot     R
# 22     1.54      0        1             1       2           Bot     R
# 23     1.56      1        1             1       2           Bot     R
# 24     1.56      2        1             1       2           Bot     R
# 25     1.58      3        1             1       2           Bot     R
# 157    1.51      0        1             2       6           Top     R
#
#     p_throws  bat_score  fld_score  at_bat_number  pitch_number  game_pk  \
# 0          L          0          0              4             1   746821
# 1          L          0          0              4             2   746821
# 2          L          0          0              4             3   746821
# 3          L          0          0              4             4   746821
# 4          L          0          0              4             5   746821
# 5          L          0          0              4             6   746821
# 6          L          0          0              4             7   746821
# 7          L          0          0              5             1   746821
# 8          L          0          0              6             1   746821
# 9          L          0          0              6             2   746821
# 10         L          0          0              7             1   746821
# 11         L          0          0              7             2   746821
# 12         L          0          0              7             3   746821
# 13         L          0          0              7             4   746821
# 14         L          0          0             12             1   746821
# 15         L          0          0             12             2   746821
# 16         L          0          0             12             3   746821
# 17         L          0          0             13             1   746821
# 18         L          0          0             13             2   746821
# 19         L          0          0             13             3   746821
# 20         L          0          0             13             4   746821
# 21         L          0          0             14             1   746821
# 22         L          0          0             14             2   746821
# 23         L          0          0             14             3   746821
# 24         L          0          0             14             4   746821
# 25         L          0          0             14             5   746821
# 157        L          2          3             42             2   746497
#
#      batter  pitcher      description           events
# 0    643217   669373             ball  batter still up
# 1    643217   669373             foul  batter still up
# 2    643217   669373             ball  batter still up
# 3    643217   669373  swinging_strike  batter still up
# 4    643217   669373             foul  batter still up
# 5    643217   669373             foul  batter still up
# 6    643217   669373  swinging_strike        strikeout
# 7    660162   669373    hit_into_play        field_out
# 8    673357   669373    called_strike  batter still up
# 9    673357   669373    hit_into_play           single
# 10   650391   669373         foul_tip  batter still up
# 11   650391   669373             ball  batter still up
# 12   650391   669373             ball  batter still up
# 13   650391   669373    hit_into_play        field_out
# 14   683734   669373             ball  batter still up
# 15   683734   669373             ball  batter still up
# 16   683734   669373    hit_into_play           single
# 17   657557   669373         foul_tip  batter still up
# 18   657557   669373     blocked_ball  batter still up
# 19   657557   669373    called_strike  batter still up
# 20   657557   669373  swinging_strike        strikeout
# 21   607680   669373    called_strike  batter still up
# 22   607680   669373             ball  batter still up
# 23   607680   669373             ball  batter still up
# 24   607680   669373             ball  batter still up
# 25   607680   669373             foul  batter still up
# 157  669127   669373             foul  batter still up

# %% [markdown]
# Perfect. Now that the only missing values are in the release_spin_rate and spin_axis, I can impute these based on the averages from that spin type.

# %%
# Impute 'release_spin_rate' and 'spin_axis' based on the mean of their respective 'pitch_type' group
skubal_2024['release_spin_rate'] = skubal_2024.groupby('pitch_type')['release_spin_rate'].transform(lambda x: x.fillna(x.mean()))
skubal_2024['spin_axis'] = skubal_2024.groupby('pitch_type')['spin_axis'].transform(lambda x: x.fillna(x.mean()))

# %% [markdown]
# Let's recheck missing data.

# %%
pd.DataFrame({
    'sale_2024_missing': sale_2024.isna().sum(),
    'skubal_2024_missing': skubal_2024.isna().sum()
})
# Out:
#                    sale_2024_missing  skubal_2024_missing
# pitch_type                         0                    0
# release_speed                      0                    0
# release_pos_x                      0                    0
# release_pos_y                      0                    0
# release_pos_z                      0                    0
# release_spin_rate                  0                    0
# spin_axis                          0                    0
# pfx_x                              0                    0
# pfx_z                              0                    0
# plate_x                            0                    0
# plate_z                            0                    0
# sz_top                             0                    0
# sz_bot                             0                    0
# balls                              0                    0
# strikes                            0                    0
# outs_when_up                       0                    0
# inning                             0                    0
# inning_topbot                      0                    0
# stand                              0                    0
# p_throws                           0                    0
# bat_score                          0                    0
# fld_score                          0                    0
# at_bat_number                      0                    0
# pitch_number                       0                    0
# game_pk                            0                    0
# batter                             0                    0
# pitcher                            0                    0
# description                        0                    0
# events                             0                    0

# %% [markdown]
# Now want to save this data so that I don't have to rerun this script every time.

# %%
sale_2024.to_csv('sale_2024_cleaned.csv', index=False)
skubal_2024.to_csv('skubal_2024_cleaned.csv', index=False)

# %% [markdown]
# # Next Steps
#
# The data is now "clean". Outliers are still there, the data is not yet scaled, and the categorical data is not one-hot encoded yet. However, I want to do the EDA before I actually do this type of cleaning.
#
# Here are the next steps:
#
#
#
# 1.   Exploratory Data Analysis
# 2.   Further Data Cleaning (Outliers, One_hot_encoding, scaling)
# 3. Feature Engineering/PCA
